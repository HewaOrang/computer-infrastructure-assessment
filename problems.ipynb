# %% [markdown]
# # Assessment Problems

# %% [markdown]
# # Problem 1: Data from yFinance
# https://github.com/ranaroussi/yfinance?tab=readme-ov-file

# %%
# Dates and times.
import datetime as dt

# Data frames.
import pandas as pd

# Yahoo Finance data.
import yfinance as yf

# Numaerical arrays.
import numpy as np

# Plotting.
import matplotlib.pyplot as plt

# %% [markdown]
# ## The download() functions

# %%
# Get data.
df = yf.download(['META', 'AAPL', 'AMZN', 'NFLX', 'GOOG',], period='5d', interval='1h')
# Out:
# C:\Users\OrangH\AppData\Local\Temp\ipykernel_328\2539342642.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(['META', 'AAPL', 'AMZN', 'NFLX', 'GOOG',], period='5d', interval='1h')
# [*********************100%***********************]  5 of 5 completed

# %% [markdown]
# ## Dates and Times
#
# https://docs.python.org/3/library/datetime.html

# %%
# Current date and time.
now =  dt.datetime.now()

# Show.
now
# Out:
# datetime.datetime(2025, 11, 28, 11, 2, 25, 512477)

# %%
# Format date and time.
now.strftime("%Y%m%d-%H%M%S")
# Out:
# '20251128-110225'

# %%
# File name.
"./data/" + now.strftime("%Y%m%d-%H%M%S") + '.csv'
# Out:
# './data/20251128-110403.csv'

# %%
# Save data as csv.
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html
df.to_csv("./data/" + dt.datetime.now().strftime("%Y%m%d-%H%M%S") + '.csv')

# %% [markdown]
# # Problem 2: Plotting Data

# %% [markdown]
# ## Save plot to file.
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.savefig.html

# %%
# Create new figure and axis.
fig, ax = plt.subplots()

# Plot all closing pieces.
df['Close'].plot(ax=ax)

# Current date and time.
now =  dt.datetime.now()
ax.set_title(f'Plot date: {now.strftime("%Y%m%d-%H%M%S")}')

# Add axis labels.
ax.set_xlabel("Date")
ax.set_ylabel("Close Price")

# Add legend.
ax.legend(loc='upper right')

# File name.
filename= "./plots/" + now.strftime("%Y%m%d-%H%M%S") + '.png'

# Save figure.
fig.savefig(filename, dpi=300)

# %% [markdown]
# # Problem 3: Script

# %% [markdown]
# The script called faang.py is saved in the root of the repository. When the script runs it's going to perform the steps in Problem 1 & 2 above.

# %% [markdown]
# ## File Listings

# %%
# Listing file in a folder.
import os

# %%
# List the files in the data folder.
data_files = os.listdir('./data')

# Show.
data_files
# Out:
# ['20251019-181625.csv',
#  '20251019-182623.csv',
#  '20251019-182700.csv',
#  '20251106-175647.csv',
#  '20251106-184835.csv',
#  '20251106-184916.csv',
#  '20251109-183820.csv']

# %% [markdown]
# ## Sorting
# https://docs.python.org/3/howto/sorting.html

# %%
# Sort the list of files.
sorted(data_files)
# Out:
# ['20251019-181625.csv',
#  '20251019-182623.csv',
#  '20251019-182700.csv',
#  '20251106-175647.csv',
#  '20251106-184835.csv',
#  '20251106-184916.csv',
#  '20251109-183820.csv']

# %%
# Sort the list of files.
data_files.sort(reverse=True)

# Show.
data_files
# Out:
# ['20251109-183820.csv',
#  '20251106-184916.csv',
#  '20251106-184835.csv',
#  '20251106-175647.csv',
#  '20251019-182700.csv',
#  '20251019-182623.csv',
#  '20251019-181625.csv']

# %%
# The latest file.
data_files[0]
# Out:
# '20251109-183820.csv'

# %% [markdown]
# ## Reading

# %%
# Read the csv file.
df = pd.read_csv(f'./data/{data_files[0]}', header=[0, 1], index_col=0, parse_dates=True)

# show.
# df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 # Read the csv file.
# ----> 2 df = pd.read_csv(f'./data/{data_files[0]}', header=[0, 1], index_col=0, parse_dates=True)
#
# NameError: name 'data_files' is not defined

# %%
# Look at the row index.
df.index
# Out:
# DatetimeIndex(['2025-11-03 14:30:00+00:00', '2025-11-03 15:30:00+00:00',
#                '2025-11-03 16:30:00+00:00', '2025-11-03 17:30:00+00:00',
#                '2025-11-03 18:30:00+00:00', '2025-11-03 19:30:00+00:00',
#                '2025-11-03 20:30:00+00:00', '2025-11-04 14:30:00+00:00',
#                '2025-11-04 15:30:00+00:00', '2025-11-04 16:30:00+00:00',
#                '2025-11-04 17:30:00+00:00', '2025-11-04 18:30:00+00:00',
#                '2025-11-04 19:30:00+00:00', '2025-11-04 20:30:00+00:00',
#                '2025-11-05 14:30:00+00:00', '2025-11-05 15:30:00+00:00',
#                '2025-11-05 16:30:00+00:00', '2025-11-05 17:30:00+00:00',
#                '2025-11-05 18:30:00+00:00', '2025-11-05 19:30:00+00:00',
#                '2025-11-05 20:30:00+00:00', '2025-11-06 14:30:00+00:00',
#                '2025-11-06 15:30:00+00:00', '2025-11-06 16:30:00+00:00',
#                '2025-11-06 17:30:00+00:00', '2025-11-06 18:30:00+00:00',
#                '2025-11-06 19:30:00+00:00', '2025-11-06 20:30:00+00:00',
#                '2025-11-07 14:30:00+00:00', '2025-11-07 15:30:00+00:00',
#                '2025-11-07 16:30:00+00:00', '2025-11-07 17:30:00+00:00',
#                '2025-11-07 18:30:00+00:00', '2025-11-07 19:30:00+00:00',
#                '2025-11-07 20:30:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='Datetime', freq=None)

# %%
# Plot
df['Close'].plot()
# Out:
# <Axes: xlabel='Datetime'>

# %% [markdown]
# ## End
