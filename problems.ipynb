# %% [markdown]
# # yFinance

# %%
1 # Yahoo Finance data.
2 import yfinance as yf
# Out:
#   Cell In[1], line 2
#     2 import yfinance as yf
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# 1

# %% [markdown]
# ## End
